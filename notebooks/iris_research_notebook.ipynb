# %% [markdown]
# # ML Pipeline — Research Notebook
#
# Этот ноутбук предназначен для EDA и экспериментов с моделью Iris.

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris(as_frame=True)
df = iris.frame

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df, hue='target')
plt.show()

# %%
import os

# 1. Выйти на уровень вверх
os.chdir("..")

print("Текущая директория после выхода вверх:", os.getcwd())

# 2. Перейти в data/raw
os.makedirs("data/raw", exist_ok=True)
os.chdir("data/raw")

print("Текущая директория (data/raw):", os.getcwd())

# 3. СКАЧАТЬ iris.csv в ЭТУ папку
from sklearn.datasets import load_iris
import pandas as pd

df = load_iris(as_frame=True).frame
df.to_csv("iris.csv", index=False)

print("iris.csv создан по пути:", os.path.abspath("iris.csv"))
# Out:
# Текущая директория после выхода вверх: C:\Users\alial\PycharmProjects\Ml Pipeline Template
# Текущая директория (data/raw): C:\Users\alial\PycharmProjects\Ml Pipeline Template\data\raw
# iris.csv создан по пути: C:\Users\alial\PycharmProjects\Ml Pipeline Template\data\raw\iris.csv
